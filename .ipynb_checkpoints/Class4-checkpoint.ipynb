# %% [markdown]
# # Mini Challenge 1
# ### Use what we learned last class to create a simple linked list that allows us to append and insert new nodes.
#
# The following last cases can be used to validate your results:
#
# ```
# mylist = LinkedList()
# for i in range(5):
#     my list.append(i)
#
# current = mylist.head
# for i in range(5):
#     assert current.data = i
#
# mylist.insert(0, -1)
#
# assert mylist.head.data == -1
# ```

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None
            
    def append(self, item):
        if not self.head:
            new_node = Node(item)
            self.head = new_node
        else:
            current = self.head
            while current.next:
                current = current.next
            new_node = Node(item)
            current.next = new_node
        
    def insert(self, index, item):
            new_node = Node(item)
            if not self.head:
                self.head = new_node
            elif index == 0:
                new_node.next = self.head
                self.head = new_node
            else:
                counter = 0
                current = self.head
                prev = None
                while current.next and index != counter:
                    prev = current
                    current = current.next
                    counter += 1
                if index == counter:
                    prev.next = new_node
                    new_node.next = current
                else:
                    current.next = new_node
                    
    def remove(self, value):
        current = self.head
        if not current:
            raise ValueError("There's nothing to remove")
        if current.data == value:
            self.head == curent.next
            
        else:
            prev = None
            while current.next and current.data != value:
                prev = current
                current = current.next
            if current.data == value:
                prev.next = current.next
            else:
                raise ValueError ("%s is not in list." % value)
                
    def __str__(self):
        output_str = "["
        current = self.head
        output_str += "%s" % current.data
        current = current.next
        while current:
            output_str += ", %s" % current.data
            current = current.next
        output_str += "]"
        return output_str
    
    def __len__(self):
        current = self.head
        length = 0
        while current:
            current = current.next
            length += 1
        return length
    
    def getCount(self):
        temp = self.head
        i = 0
        while (temp != None):
            i += 1
            temp = temp.next
        return i
    
    def Index(self, searchValue):
        temp = self.head
        found = 0
        i = 0 
        if(temp != None):
            while (temp != None):
                i += 1
                if(temp.data == searchValue):
                    found += 1
                    break
                temp = temp.next
            if(found == 1):
                print(searchValue,"is found at index =", i)
            else:
                print(searchValue,"is not found in the list.")
        else:
            print("The list is empty.")
        
mylist = LinkedList()
for i in range(5):
    mylist.append(i)

current = mylist.head

for i in range(5):
    assert current.data == i
    current = current.next
    
mylist.insert(0, -1)

assert mylist.head.data == -1

print(mylist)
print(len(mylist))
print(mylist.getCount())
mylist.Index(4)
# Out:
# [-1, 0, 1, 2, 3, 4]
# 6
# 6
# 4 is found at index = 6

# %%
class DNode:
    def __init__(self,data):
        self.data = data
        self.prev = None
        self.next = None
    
class DoublyLinkedList:
    def __init__(self):
        self.head = None
    
    def append(self, item):
        new_node = DNode(item)
        if not self.head:
            self.head = new_node
        else:
            current = self.head
            while current.next
                current = current.next
            current.next = new_node
            new_node.prev = current
